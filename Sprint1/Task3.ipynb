// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания 3

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [Описание задачи:
// Создать базовый класс Employee в C#, который будет представлять информацию о
// сотрудниках компании. На основе этого класса разработать 2-3 производных
// класса, демонстрирующих принципы наследования и полиморфизма. В каждом из
// классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
// ]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class Employee
{
    private string name;
    private int salary;
    private int age;

    public int Age
    {
        get { return age; }
        set
        {
            if (value > 0)
                age = value;
            else
                throw new ArgumentOutOfRangeException("Возраст не может быть отрицательным!");
        }
    }

    public int Salary
    {
        get { return salary; }
        set
        {
            if (value > 0)
                salary = value;
            else
                throw new ArgumentOutOfRangeException("Зарплата не может быть отрицательной!");
        }
    }
    public string Name
    {
        get { return name; }
        set {name = value; }
    }

    public Employee(string name, int age, int salary)
    {
        Name = name;
        Age = age;
        Salary = salary;
    }


    public virtual string GetInfo()
    {
        return $"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary} рублей";
    }

    public virtual void Work()
    {
        Console.WriteLine($"Сотрудник {Name} работает");
    }

    public virtual void TakeVacation()
    {
        Console.WriteLine($"Сотрудник {Name} взял отпуск");
    }

     public virtual void Display()
    {
        Console.WriteLine(GetInfo());
    }

    public virtual void Compare(Employee otherEmployee)
    {
        int priceDifference = this.Salary - otherEmployee.Salary;
        if (Salary < otherEmployee.Salary)
        {
            Console.WriteLine ($"{Name} зарабатывает меньше, чем {otherEmployee.Name} на {-priceDifference} руб.");
        }
        else if (Salary > otherEmployee.Salary)
        {
            Console.WriteLine ($"{Name} зарабатывает больше, чем {otherEmployee.Name} на {priceDifference} руб.");
        }
        else
        {
            Console.WriteLine ($"{Name} и {otherEmployee.Name} имеют одинаковую зарплату.");
        }
    }

}

public class Manager : Employee
{
    public int SubordinatesCount { get; set; }

    public Manager(string name, int age, int salary, int subordinatescount) : base (name, age, salary)
    {
        SubordinatesCount = subordinatescount;
    }

    public override void Work()
    {
        Console.WriteLine($"Менеджер {Name} управляет командой");
    }

    public override void Display()
    {
        Console.WriteLine($"{GetInfo()}, Количество подчиненных: {SubordinatesCount}");
    }

}

public class Developer : Employee
{
    public string Specialization { get; set; }

    public Developer(string name, int age, int salary, string specialization) : base (name, age, salary)
    {
        Specialization = specialization;
    }

    public override void TakeVacation()
    {
        Console.WriteLine($"Разработчик {Name} взял отпуск, необходимо согласовать с проектными сроками.");
    }

    public override void Display()
    {
        Console.WriteLine($"{GetInfo()}, Специализация: {Specialization}");
    }

}

public class Designer : Employee
{
    public string DesignStyle { get; set; }

    public Designer(string name, int age, int salary, string designstyle) : base (name, age, salary)
    {
        DesignStyle = designstyle;
    }

    public override void Work()
    {
        Console.WriteLine($"Дизайнер {Name} работает над дизайн-проектом Геология");
    }

    public override void Display()
    {
        Console.WriteLine($"{GetInfo()}, Стиль дизайна: {DesignStyle}");
    }

}

Employee first = new Manager("Элиз Бентли", 39, 118000, 23);
Employee second = new Developer("Томас Мюллер", 37, 95000, "Веб-разработка");
Employee third = new Designer("Кэтти Дейва", 29 , 89000, "Модерн");

first.Display(); first.Work();
second.Display(); second.TakeVacation();
third.Display(); third.Work();
first.Compare(third);
// Out:
// Имя: Элиз Бентли, Возраст: 39, Зарплата: 118000 рублей, Количество подчиненных: 23
// Менеджер Элиз Бентли управляет командой
// Имя: Томас Мюллер, Возраст: 37, Зарплата: 95000 рублей, Специализация: Веб-разработка
// Разработчик Томас Мюллер взял отпуск, необходимо согласовать с проектными сроками.
// Имя: Кэтти Дейва, Возраст: 29, Зарплата: 89000 рублей, Стиль дизайна: Модерн
// Дизайнер Кэтти Дейва работает над дизайн-проектом Геология
// Элиз Бентли зарабатывает больше, чем Кэтти Дейва на 29000 руб.
